# %% [markdown]
# # Olympics Dataset - Case Study

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Question - 1:
#
# Create a dataframe with following data cleanup to make this file redable.
#
# Create a function load_data to read CSV file and convert CSV data to dataframe.
# Skip first row.
# Rename column containing 01, 02 and 03 to Gold, Silver and Bronze.
# Split country name and country code and add country name as data frame index.
# Remove extra unnecessary characters from country name.
# Drop the column Totals.
# Return dataframe.

# %%
#filepath = '/home/nikhil/Documents/olympics.csv'
def load_data(filepath):
    dataset = pd.read_csv(filepath, skiprows=1)
    rename_columns = {'Unnamed: 0': 'Country',
                 '01 !': 'Gold',
                 '02 !': 'Silver',
                 '03 !': 'Bronze',
                 '01 !.1': 'Gold',
                 '02 !.1': 'Silver',
                 '03 !.1': 'Bronze',
                 '01 !.2': 'Gold',
                 '02 !.2': 'Silver',
                 '03 !.2': 'Bronze',
                 'Total.1': 'Total'}
    dataset.rename(columns = rename_columns, inplace = True)
    country_names = [x.split('\xc2\xa0(')[0] for x in dataset.iloc[:,0]]
    dataset.set_index(pd.Series(country_names), inplace=True)
    dataset.iloc[:,0] = country_names
    dataset.drop('Total', axis = 1, inplace = True)
    return dataset

# %%
dataset = load_data('/home/nikhil/Documents/olympics.csv')

# %%
# def split(series):
#     for string in series:
#         country_names = string.split('\xc2\xa0(')[0]
#         dataset.set_index(pd.Series(country_names), inplace=True)

# %%
# split(dataset['Country'])

# %%
# dataset.set_index(pd.Series(country_names), inplace = True)

# %%
dataset.head()
# Out:
#                  Country  # Summer  Gold  Silver  Bronze  # Winter  Gold  \
# Afghanistan  Afghanistan        13     0       0       2         0     0
# Algeria          Algeria        12     5       2       8         3     0
# Argentina      Argentina        23    18      24      28        18     0
# Armenia          Armenia         5     1       2       9         6     0
# Australasia  Australasia         2     3       4       5         0     0
#
#              Silver  Bronze  # Games  Gold  Silver  Bronze  Combined total
# Afghanistan       0       0       13     0       0       2               2
# Algeria           0       0       15     5       2       8              15
# Argentina         0       0       41    18      24      28              70
# Armenia           0       0       11     1       2       9              12
# Australasia       0       0        2     3       4       5              12

# %% [markdown]
# ### Question - 2:
#
# Write a function to get first country details from dataframe we got from load_data function.
#
# Create a function first_country.
# Return results for first country.

# %%
def first_country(df):
    result = dataset.iloc[0,:]
    return result

# %%
first_country(dataset)
# Out:
# Country           Afghanistan
# # Summer                   13
# Gold                        0
# Silver                      0
# Bronze                      2
# # Winter                    0
# Gold                        0
# Silver                      0
# Bronze                      0
# # Games                    13
# Gold                        0
# Silver                      0
# Bronze                      2
# Combined total              2
# Name: Afghanistan, dtype: object

# %% [markdown]
# ### Question - 3:
#
# Which country has won the most gold medals in summer games?
#
# Create a function gold_medal to get name of country who won most gold medals.
# Return country name.

# %%
def gold_medal(df):
    return df.iloc[:146,2].idxmax()

# %%
gold_medal(dataset)
# Out:
# 'United States'

# %% [markdown]
# ### Question - 4:
#
# Which country had the biggest difference between their summer and winter gold medal counts?
#
# Create a function biggest_difference_in_gold_medal to get name of country who has biggest difference between their summer and winter gold medal counts.
# Return country name.

# %%
def biggest_difference_in_gold_medal (df):
    return (df.iloc[0:146,2]-df.iloc[0:146,6]).argmax()

# %%
biggest_difference_in_gold_medal(dataset)
# Out:
# 'United States'

# %% [markdown]
# ### Question - 5:
#
# Write a function to update the dataframe to include a new column called "Points" for Games which is a weighted value where each gold medal counts for 3 points, silver medals for 2 points, and bronze medals for 1 point. The function should return only the column (a Series object) which you created.
#
# Create a function get_points.
# Return dataframe with points column and index.

# %%
def get_points(df):
    df['points'] = 3*(df['Gold'].sum(axis=1)) + 2*(df['Silver'].sum(axis=1)) + 1*(df['Bronze'].sum(axis=1))
    return df.iloc[:,14]

# %%
get_points(dataset)
# Out:
# Afghanistan                             4
# Algeria                                54
# Argentina                             260
# Armenia                                32
# Australasia                            44
# Australia                            1846
# Austria                              1138
# Azerbaijan                             86
# Bahamas                                48
# Bahrain                                 2
# Barbados                                2
# Belarus                               308
# Belgium                               552
# Bermuda                                 2
# Bohemia                                10
# Botswana                                4
# Brazil                                368
# British West Indies                     4
# Bulgaria                              822
# Burundi                                 6
# Cameroon                               24
# Canada                               1692
# Chile                                  48
# China                                2240
# Colombia                               58
# Costa Rica                             14
# Ivory Coast                             4
# Croatia                               134
# Cuba                                  840
# Cyprus                                  4
#                                     ...
# Sri Lanka                               8
# Sudan                                   4
# Suriname                                8
# Sweden                               2434
# Switzerland                          1260
# Syria                                  12
# Chinese Taipei                         64
# Tajikistan                              8
# Tanzania                                8
# Thailand                               88
# Togo                                    2
# Tonga                                   4
# Trinidad and Tobago                    54
# Tunisia                                38
# Turkey                                382
# Uganda                                 28
# Ukraine                               440
# United Arab Emirates                    6
# United States                       11368
# Uruguay                                32
# Uzbekistan                             76
# Venezuela                              36
# Vietnam                                 8
# Virgin Islands                          4
# Yugoslavia                            342
# Independent Olympic Participants        8
# Zambia                                  6
# Zimbabwe                               36
# Mixed team                             76
# Totals                              69696
# Name: points, dtype: int64

# %%
dataset.head()
# Out:
#                  Country  # Summer  Gold  Silver  Bronze  # Winter  Gold  \
# Afghanistan  Afghanistan        13     0       0       2         0     0
# Algeria          Algeria        12     5       2       8         3     0
# Argentina      Argentina        23    18      24      28        18     0
# Armenia          Armenia         5     1       2       9         6     0
# Australasia  Australasia         2     3       4       5         0     0
#
#              Silver  Bronze  # Games  Gold  Silver  Bronze  Combined total  \
# Afghanistan       0       0       13     0       0       2               2
# Algeria           0       0       15     5       2       8              15
# Argentina         0       0       41    18      24      28              70
# Armenia           0       0       11     1       2       9              12
# Australasia       0       0        2     3       4       5              12
#
#              points
# Afghanistan       4
# Algeria          54
# Argentina       260
# Armenia          32
# Australasia      44

# %%
from sklearn.preprocessing import LabelEncoder
def label_encoder(df,list_of_columns):
    try:
        for col in list_of_columns:
            encoder = LabelEncoder()
            df[col] = encoder.fit_transform(df[col])
        return df
    except KeyError:
        print("exception occured")
label_encoder(dataset,['Country'])
# Out:
#                                   Country  # Summer  Gold  Silver  Bronze  \
# Afghanistan                             0        13     0       0       2
# Algeria                                 1        12     5       2       8
# Argentina                               2        23    18      24      28
# Armenia                                 3         5     1       2       9
# Australasia                             4         2     3       4       5
# Australia                               5        25   139     152     177
# Austria                                 6        26    18      33      35
# Azerbaijan                              7         5     6       5      15
# Bahamas                                 8        15     5       2       5
# Bahrain                                 9         8     0       0       1
# Barbados                               10        11     0       0       1
# Belarus                                11         5    12      24      39
# Belgium                                12        25    37      52      53
# Bermuda                                13        17     0       0       1
# Bohemia                                14         3     0       1       3
# Botswana                               15         9     0       1       0
# Brazil                                 16        21    23      30      55
# British West Indies                    17         1     0       0       2
# Bulgaria                               18        19    51      85      78
# Burundi                                19         5     1       0       0
# Cameroon                               20        13     3       1       1
# Canada                                 21        25    59      99     121
# Chile                                  22        22     2       7       4
# China                                  23         9   201     146     126
# Colombia                               25        18     2       6      11
# Costa Rica                             26        14     1       1       2
# Ivory Coast                            64        12     0       1       0
# Croatia                                27         6     6       7      10
# Cuba                                   28        19    72      67      70
# Cyprus                                 29         9     0       1       0
# ...                                   ...       ...   ...     ...     ...
# Sri Lanka                             117        16     0       2       0
# Sudan                                 118        11     0       1       0
# Suriname                              119        11     1       0       1
# Sweden                                120        26   143     164     176
# Switzerland                           121        27    47      73      65
# Syria                                 122        12     1       1       1
# Chinese Taipei                         24        13     2       7      12
# Tajikistan                            123         5     0       1       2
# Tanzania                              124        12     0       2       0
# Thailand                              125        15     7       6      11
# Togo                                  126         9     0       0       1
# Tonga                                 127         8     0       1       0
# Trinidad and Tobago                   129        16     2       5      11
# Tunisia                               130        13     3       3       4
# Turkey                                131        21    39      25      24
# Uganda                                132        14     2       3       2
# Ukraine                               133         5    33      27      55
# United Arab Emirates                  135         8     1       0       0
# United States                         136        26   976     757     666
# Uruguay                               138        20     2       2       6
# Uzbekistan                            139         5     5       5      10
# Venezuela                             140        17     2       2       8
# Vietnam                               141        14     0       2       0
# Virgin Islands                        142        11     0       1       0
# Yugoslavia                            144        16    26      29      28
# Independent Olympic Participants       56         1     0       1       2
# Zambia                                145        12     0       1       1
# Zimbabwe                              146        12     3       4       1
# Mixed team                             80         3     8       5       4
# Totals                                128        27  4809    4775    5130
#
#                                   # Winter  Gold  Silver  Bronze  # Games  \
# Afghanistan                              0     0       0       0       13
# Algeria                                  3     0       0       0       15
# Argentina                               18     0       0       0       41
# Armenia                                  6     0       0       0       11
# Australasia                              0     0       0       0        2
# Australia                               18     5       3       4       43
# Austria                                 22    59      78      81       48
# Azerbaijan                               5     0       0       0       10
# Bahamas                                  0     0       0       0       15
# Bahrain                                  0     0       0       0        8
# Barbados                                 0     0       0       0       11
# Belarus                                  6     6       4       5       11
# Belgium                                 20     1       1       3       45
# Bermuda                                  7     0       0       0       24
# Bohemia                                  0     0       0       0        3
# Botswana                                 0     0       0       0        9
# Brazil                                   7     0       0       0       28
# British West Indies                      0     0       0       0        1
# Bulgaria                                19     1       2       3       38
# Burundi                                  0     0       0       0        5
# Cameroon                                 1     0       0       0       14
# Canada                                  22    62      56      52       47
# Chile                                   16     0       0       0       38
# China                                   10    12      22      19       19
# Colombia                                 1     0       0       0       19
# Costa Rica                               6     0       0       0       20
# Ivory Coast                              0     0       0       0       12
# Croatia                                  7     4       6       1       13
# Cuba                                     0     0       0       0       19
# Cyprus                                  10     0       0       0       19
# ...                                    ...   ...     ...     ...      ...
# Sri Lanka                                0     0       0       0       16
# Sudan                                    0     0       0       0       11
# Suriname                                 0     0       0       0       11
# Sweden                                  22    50      40      54       48
# Switzerland                             22    50      40      48       49
# Syria                                    0     0       0       0       12
# Chinese Taipei                          11     0       0       0       24
# Tajikistan                               4     0       0       0        9
# Tanzania                                 0     0       0       0       12
# Thailand                                 3     0       0       0       18
# Togo                                     1     0       0       0       10
# Tonga                                    1     0       0       0        9
# Trinidad and Tobago                      3     0       0       0       19
# Tunisia                                  0     0       0       0       13
# Turkey                                  16     0       0       0       37
# Uganda                                   0     0       0       0       14
# Ukraine                                  6     2       1       4       11
# United Arab Emirates                     0     0       0       0        8
# United States                           22    96     102      84       48
# Uruguay                                  1     0       0       0       21
# Uzbekistan                               6     1       0       0       11
# Venezuela                                4     0       0       0       21
# Vietnam                                  0     0       0       0       14
# Virgin Islands                           7     0       0       0       18
# Yugoslavia                              14     0       3       1       30
# Independent Olympic Participants         0     0       0       0        1
# Zambia                                   0     0       0       0       12
# Zimbabwe                                 1     0       0       0       13
# Mixed team                               0     0       0       0        3
# Totals                                  22   959     958     948       49
#
#                                   Gold  Silver  Bronze  Combined total  points
# Afghanistan                          0       0       2               2       4
# Algeria                              5       2       8              15      54
# Argentina                           18      24      28              70     260
# Armenia                              1       2       9              12      32
# Australasia                          3       4       5              12      44
# Australia                          144     155     181             480    1846
# Austria                             77     111     116             304    1138
# Azerbaijan                           6       5      15              26      86
# Bahamas                              5       2       5              12      48
# Bahrain                              0       0       1               1       2
# Barbados                             0       0       1               1       2
# Belarus                             18      28      44              90     308
# Belgium                             38      53      56             147     552
# Bermuda                              0       0       1               1       2
# Bohemia                              0       1       3               4      10
# Botswana                             0       1       0               1       4
# Brazil                              23      30      55             108     368
# British West Indies                  0       0       2               2       4
# Bulgaria                            52      87      81             220     822
# Burundi                              1       0       0               1       6
# Cameroon                             3       1       1               5      24
# Canada                             121     155     173             449    1692
# Chile                                2       7       4              13      48
# China                              213     168     145             526    2240
# Colombia                             2       6      11              19      58
# Costa Rica                           1       1       2               4      14
# Ivory Coast                          0       1       0               1       4
# Croatia                             10      13      11              34     134
# Cuba                                72      67      70             209     840
# Cyprus                               0       1       0               1       4
# ...                                ...     ...     ...             ...     ...
# Sri Lanka                            0       2       0               2       8
# Sudan                                0       1       0               1       4
# Suriname                             1       0       1               2       8
# Sweden                             193     204     230             627    2434
# Switzerland                         97     113     113             323    1260
# Syria                                1       1       1               3      12
# Chinese Taipei                       2       7      12              21      64
# Tajikistan                           0       1       2               3       8
# Tanzania                             0       2       0               2       8
# Thailand                             7       6      11              24      88
# Togo                                 0       0       1               1       2
# Tonga                                0       1       0               1       4
# Trinidad and Tobago                  2       5      11              18      54
# Tunisia                              3       3       4              10      38
# Turkey                              39      25      24              88     382
# Uganda                               2       3       2               7      28
# Ukraine                             35      28      59             122     440
# United Arab Emirates                 1       0       0               1       6
# United States                     1072     859     750            2681   11368
# Uruguay                              2       2       6              10      32
# Uzbekistan                           6       5      10              21      76
# Venezuela                            2       2       8              12      36
# Vietnam                              0       2       0               2       8
# Virgin Islands                       0       1       0               1       4
# Yugoslavia                          26      32      29              87     342
# Independent Olympic Participants     0       1       2               3       8
# Zambia                               0       1       1               2       6
# Zimbabwe                             3       4       1               8      36
# Mixed team                           8       5       4              17      76
# Totals                            5768    5733    6078           17579   69696
#
# [147 rows x 15 columns]

# %% [markdown]
# ### Question - 6
#
# Write a function to perform k-means clustering.
#
# Create a fucntion k_means
# return cluster centers

# %%
from sklearn.cluster import KMeans
def k_means(df,n,k):
    kmeans = KMeans(n_clusters=n, random_state=k).fit(df)
    #print kmeans.labels_
    return kmeans.cluster_centers_

# %%
k_means(dataset.iloc[0:146,:],4,10)
# Out:
# array([[  7.25203252e+01,   1.21626016e+01,   7.44715447e+00,
#           9.15447154e+00,   1.05934959e+01,   4.52032520e+00,
#           4.30894309e-01,   5.52845528e-01,   6.26016260e-01,
#           1.66829268e+01,   7.87804878e+00,   9.70731707e+00,
#           1.12195122e+01,   2.88048780e+01,   1.08536585e+02],
#        [  1.36000000e+02,   2.60000000e+01,   9.76000000e+02,
#           7.57000000e+02,   6.66000000e+02,   2.20000000e+01,
#           9.60000000e+01,   1.02000000e+02,   8.40000000e+01,
#           4.80000000e+01,   1.07200000e+03,   8.59000000e+02,
#           7.50000000e+02,   2.68100000e+03,   1.13680000e+04],
#        [  7.26470588e+01,   1.92941176e+01,   1.00705882e+02,
#           1.01764706e+02,   1.14411765e+02,   1.75882353e+01,
#           3.38823529e+01,   3.43529412e+01,   3.37058824e+01,
#           3.68823529e+01,   1.34588235e+02,   1.36117647e+02,
#           1.48117647e+02,   4.18823529e+02,   1.64823529e+03],
#        [  6.24000000e+01,   2.08000000e+01,   2.41000000e+02,
#           2.32400000e+02,   2.43200000e+02,   1.72000000e+01,
#           4.68000000e+01,   4.08000000e+01,   4.28000000e+01,
#           3.80000000e+01,   2.87800000e+02,   2.73200000e+02,
#           2.86000000e+02,   8.47000000e+02,   3.39160000e+03]])
